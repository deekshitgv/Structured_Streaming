# %% [markdown]
# <img src="https://files.training.databricks.com/images/Apache-Spark-Logo_TM_200px.png" style="float: left: margin: 20px"/>
#
# # Structured Streaming
#
# ## Prerequisites
# * Web browser: **Chrome**
# * A cluster configured with **8 cores** and **DBR 6.2**
# * Run the code on the databricks Community edition workspace.

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Setup
#
# For each lesson to execute correctly, please make sure to run the **`Classroom-Setup`** cell at the<br/>
# start of the cell (see the next cell) and the **`Classroom-Cleanup`** cell at the end.

# %%
# %run "../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Preparing the Python environment...
# Defining courseware-specific utility methods...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Defining user-facing utility methods...
# Defining custom variables for this lesson...
# Initializing Databricks Academy's testing framework...
# Initializing Databricks Academy's services for generating dynamic data...
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Cleaning up the learning environment...no actions taken.
#       <div style="color:red; font-weight:bold">WARNING: This notebook was tested on DBR 6.2, but we found DBR 8.0.</div>
#       <div style="font-weight:bold">Using an untested DBR may yield unexpected results and/or various errors</div>
#       <div style="font-weight:bold">Please update your cluster configuration and/or <a href="https://academy.databricks.com/" target="_blank">download a newer version of this course</a> before proceeding.</div>
# All done!

# %% [markdown]
# Define the name of the stream we are to use later in this lesson:

# %%
myStreamName = "lab02_ps"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png">Read Stream</h2>
#
# The dataset used in this exercise consists of flight information about flights from/to various airports in 2007.
#
# Run the following cell to see what the streaming data will look like.

# %%
display(
  spark.read.parquet("dbfs:/mnt/training/asa/flights/2007-01-stream.parquet/part-00000-tid-9167815511861375854-22d81a30-d5b4-43d0-9216-0c20d14c3f54-178-c000.snappy.parquet")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DepartureAt</th><th>FlightDate</th><th>DepTime</th><th>CRSDepTime</th><th>ArrTime</th><th>CRSArrTime</th><th>UniqueCarrier</th><th>FlightNum</th><th>TailNum</th><th>ActualElapsedTime</th><th>CRSElapsedTime</th><th>AirTime</th><th>ArrDelay</th><th>DepDelay</th><th>Origin</th><th>Dest</th><th>Distance</th><th>TaxiIn</th><th>TaxiOut</th><th>Cancelled</th><th>CancellationCode</th><th>Diverted</th><th>CarrierDelay</th><th>WeatherDelay</th><th>NASDelay</th><th>SecurityDelay</th><th>LateAircraftDelay</th></tr></thead><tbody><tr><td>2007-01-01T00:01:00.000+0000</td><td>2007-01-01</td><td>00:01</td><td>22:05</td><td>07:24</td><td>05:33</td><td>NW</td><td>96</td><td>N593NW</td><td>323</td><td>328</td><td>293</td><td>111</td><td>116</td><td>HNL</td><td>SEA</td><td>2677</td><td>5</td><td>25</td><td>0</td><td>null</td><td>0</td><td>111</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:01:00.000+0000</td><td>2007-01-01</td><td>00:01</td><td>23:45</td><td>07:22</td><td>06:50</td><td>DL</td><td>704</td><td>N607DL</td><td>261</td><td>245</td><td>228</td><td>32</td><td>16</td><td>LAX</td><td>CVG</td><td>1900</td><td>7</td><td>26</td><td>0</td><td>null</td><td>0</td><td>16</td><td>0</td><td>16</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:01:00.000+0000</td><td>2007-01-01</td><td>00:01</td><td>23:30</td><td>07:05</td><td>06:42</td><td>DL</td><td>748</td><td>N380DA</td><td>244</td><td>252</td><td>221</td><td>23</td><td>31</td><td>SEA</td><td>CVG</td><td>1964</td><td>7</td><td>16</td><td>0</td><td>null</td><td>0</td><td>23</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:01:00.000+0000</td><td>2007-01-01</td><td>00:01</td><td>22:45</td><td>08:44</td><td>07:10</td><td>AA</td><td>192</td><td>N632AA</td><td>343</td><td>325</td><td>320</td><td>94</td><td>76</td><td>LAX</td><td>BOS</td><td>2611</td><td>6</td><td>17</td><td>0</td><td>null</td><td>0</td><td>51</td><td>0</td><td>18</td><td>0</td><td>25</td></tr><tr><td>2007-01-01T00:01:00.000+0000</td><td>2007-01-01</td><td>00:01</td><td>23:55</td><td>06:13</td><td>06:15</td><td>CO</td><td>434</td><td>N76504</td><td>252</td><td>260</td><td>232</td><td>-2</td><td>6</td><td>PHX</td><td>EWR</td><td>2133</td><td>5</td><td>15</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:03:00.000+0000</td><td>2007-01-01</td><td>00:03</td><td>23:55</td><td>02:48</td><td>02:32</td><td>YV</td><td>2876</td><td>N921FJ</td><td>105</td><td>97</td><td>80</td><td>16</td><td>8</td><td>LAS</td><td>ELP</td><td>584</td><td>4</td><td>21</td><td>0</td><td>null</td><td>0</td><td>16</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:04:00.000+0000</td><td>2007-01-01</td><td>00:04</td><td>00:10</td><td>07:34</td><td>07:38</td><td>NW</td><td>336</td><td>N523US</td><td>270</td><td>268</td><td>233</td><td>-4</td><td>-6</td><td>LAX</td><td>DTW</td><td>1979</td><td>13</td><td>24</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:04:00.000+0000</td><td>2007-01-01</td><td>00:04</td><td>23:57</td><td>07:32</td><td>07:16</td><td>US</td><td>49</td><td>N828AW</td><td>268</td><td>259</td><td>243</td><td>16</td><td>7</td><td>LAS</td><td>DCA</td><td>2089</td><td>3</td><td>22</td><td>0</td><td>null</td><td>0</td><td>7</td><td>0</td><td>9</td><td>0</td><td>0</td></tr><tr><td>2007-01-01T00:04:00.000+0000</td><td>2007-01-01</td><td>00:04</td><td>20:50</td><td>02:04</td><td>23:00</td><td>AA</td><td>2376</td><td>N509AA</td><td>120</td><td>130</td><td>99</td><td>184</td><td>194</td><td>DFW</td><td>ORD</td><td>802</td><td>12</td><td>9</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>184</td></tr><tr><td>2007-01-01T00:05:00.000+0000</td><td>2007-01-01</td><td>00:05</td><td>23:55</td><td>05:30</td><td>05:27</td><td>CO</td>< ...

# %% [markdown]
# Start by reading the stream.
#
# For this step you will need to:
# 1. Starting with `spark`, an instance of `SparkSession`, and get the `DataStreamReader`
# 2. We will make sure to only consume only 1 file per trigger for this Data.
# 3. We have Specified the stream's schema using the instance `dataSchema`
# 4. Use `dsr.parquet()` to specify the stream's file type and source directory, `dataPath`
#
# When you are done, run the TEST cell that follows to verify your results.

# %%
# TODO
dataSchema = "DepartureAt timestamp, FlightDate string, DepTime string, CRSDepTime string, ArrTime string, CRSArrTime string, UniqueCarrier string, FlightNum integer, TailNum string, ActualElapsedTime string, CRSElapsedTime string, AirTime string, ArrDelay string, DepDelay string, Origin string, Dest string, Distance string, TaxiIn string, TaxiOut string, Cancelled integer, CancellationCode string, Diverted integer, CarrierDelay string, WeatherDelay string, NASDelay string, SecurityDelay string, LateAircraftDelay string"

dataPath = "dbfs:/mnt/training/asa/flights/2007-01-stream.parquet"

initialDF = (spark.readStream
             .option("maxFilesPerTrigger", 1)
             .schema(dataSchema)
             .parquet(dataPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Calculate the total of all delays</h2>
#
# We want to calculate (and later graph) the total delay of each flight
# 1. Start with `initialDF` from the previous cell.
# 2. Convert the following columns from `String` to `Integer`: `CarrierDelay`, `WeatherDelay`, `NASDelay`, `SecurityDelay` and `LateAircraftDelay`
# 3. Add the column `TotalDelay` which is the sum of the other 5 delays
# 4. Filter the flights by `UniqueCarrier` down to the carriers **AS**, **AQ**, **HA** and **F9**
# 5. Filter the results to non-zero delay's (`TotalDelay` > 0)
# 6. Assign the final DataFrame to `delaysDF`

# %%
# TODO
from pyspark.sql.functions import *
delaysDF = (initialDF
  .withColumn("CarrierDelay", col("CarrierDelay").cast("integer"))  # Convert CarrierDelay to an Integer
  .withColumn("WeatherDelay", col("WeatherDelay").cast("integer"))  # Convert WeatherDelay to an Integer
  .withColumn("NASDelay", col("NASDelay").cast("integer"))  # Convert NASDelay to an Integer
  .withColumn("SecurityDelay", col("SecurityDelay").cast("integer"))  # Convert SecurityDelay to an Integer
  .withColumn("LateAircraftDelay", col("LateAircraftDelay").cast("integer"))  # Convert LateAircraftDelay to an Integer
  .withColumn("TotalDelay", col("CarrierDelay")+col("WeatherDelay")+col("NASDelay")+col("SecurityDelay")+col("LateAircraftDelay"))  # Sum all five as TotalDelay
  .filter(col("UniqueCarrier").isin("AS","AQ","HA","F9"))   # Filter UniqueCarrier to only "AS", "AQ", "HA" and "F9"
  .filter(col("TotalDelay") > 0)  # TotalDelay to non-zero values
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png">Plot a LIVE graph</h2>
#
# Plot `delaysDF` and give the stream the name "delays_python"
#
# Once the data is loaded, render a line graph with
# * **Keys** is set to `DepartureAt`
# * **Series groupings** is set to `UniqueCarrier`
# * **Values** is set to `TotalDelay`

# %%
initialDF.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: True</div>

# %%
# TODO
myStreamName = "delays_python"
display(delaysDF, streamName = myStreamName)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DepartureAt</th><th>FlightDate</th><th>DepTime</th><th>CRSDepTime</th><th>ArrTime</th><th>CRSArrTime</th><th>UniqueCarrier</th><th>FlightNum</th><th>TailNum</th><th>ActualElapsedTime</th><th>CRSElapsedTime</th><th>AirTime</th><th>ArrDelay</th><th>DepDelay</th><th>Origin</th><th>Dest</th><th>Distance</th><th>TaxiIn</th><th>TaxiOut</th><th>Cancelled</th><th>CancellationCode</th><th>Diverted</th><th>CarrierDelay</th><th>WeatherDelay</th><th>NASDelay</th><th>SecurityDelay</th><th>LateAircraftDelay</th><th>TotalDelay</th></tr></thead><tbody><tr><td>2007-01-01T00:06:00.000+0000</td><td>2007-01-01</td><td>00:06</td><td>23:55</td><td>05:51</td><td>05:35</td><td>F9</td><td>380</td><td>N948FR</td><td>225</td><td>220</td><td>208</td><td>16</td><td>11</td><td>DEN</td><td>FLL</td><td>1703</td><td>4</td><td>13</td><td>0</td><td>null</td><td>0</td><td>11</td><td>0</td><td>5</td><td>0</td><td>0</td><td>16</td></tr><tr><td>2007-01-01T00:34:00.000+0000</td><td>2007-01-01</td><td>00:34</td><td>23:55</td><td>01:32</td><td>00:52</td><td>AS</td><td>191</td><td>N765AS</td><td>58</td><td>57</td><td>37</td><td>40</td><td>39</td><td>ANC</td><td>FAI</td><td>261</td><td>4</td><td>17</td><td>0</td><td>null</td><td>0</td><td>39</td><td>0</td><td>1</td><td>0</td><td>0</td><td>40</td></tr><tr><td>2007-01-01T07:05:00.000+0000</td><td>2007-01-01</td><td>07:05</td><td>07:00</td><td>08:39</td><td>08:23</td><td>AS</td><td>583</td><td>N622AS</td><td>94</td><td>83</td><td>56</td><td>16</td><td>5</td><td>LAX</td><td>SFO</td><td>337</td><td>21</td><td>17</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>16</td><td>0</td><td>0</td><td>16</td></tr><tr><td>2007-01-01T08:06:00.000+0000</td><td>2007-01-01</td><td>08:06</td><td>08:10</td><td>15:45</td><td>15:25</td><td>HA</td><td>10</td><td>N590HA</td><td>459</td><td>435</td><td>432</td><td>20</td><td>-4</td><td>HNL</td><td>LAX</td><td>2556</td><td>10</td><td>17</td><td>0</td><td>null</td><td>0</td><td>20</td><td>0</td><td>0</td><td>0</td><td>0</td><td>20</td></tr><tr><td>2007-01-01T08:34:00.000+0000</td><td>2007-01-01</td><td>08:34</td><td>07:25</td><td>10:39</td><td>09:30</td><td>AS</td><td>351</td><td>N302AS</td><td>125</td><td>125</td><td>109</td><td>69</td><td>69</td><td>SFO</td><td>SEA</td><td>679</td><td>3</td><td>13</td><td>0</td><td>null</td><td>0</td><td>69</td><td>0</td><td>0</td><td>0</td><td>0</td><td>69</td></tr><tr><td>2007-01-01T08:35:00.000+0000</td><td>2007-01-01</td><td>08:35</td><td>08:30</td><td>11:48</td><td>11:30</td><td>AS</td><td>595</td><td>N972AS</td><td>193</td><td>180</td><td>168</td><td>18</td><td>5</td><td>SAN</td><td>SEA</td><td>1050</td><td>6</td><td>19</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>18</td><td>0</td><td>0</td><td>18</td></tr><tr><td>2007-01-01T09:11:00.000+0000</td><td>2007-01-01</td><td>09:11</td><td>08:05</td><td>11:10</td><td>10:22</td><td>AS</td><td>232</td><td>N786AS</td><td>119</td><td>137</td><td>98</td><td>48</td><td>66</td><td>SEA</td><td>SFO</td><td>679</td><td>5</td><td>16</td><td>0</td><td>null</td><td>0</td><td>48</td><td>0</td><td>0</td><td>0</td><td>0</td><td>48</td></tr><tr><td>2007-01-01T09:29:00.000+0000</td><td>2007-01-01</td><td>09:29</td><td>09:00</td><td>13:57</td><td>13:30</td><td>AS</td><td>196</td><td>N645AS</td><td>208</td><td>210</td><td>187</td><td>27</td><td>29</td><td>ANC</td><td>SEA</td><td>1449</td><td>7</td><td>14</td><td>0</td><td>null</td><td>0</td><td>27</td><td>0</td><td>0</td><td>0</td><td>0</td><td>27</td></tr><tr><td>2007-01-01T09:42:00.000+0000</td><td>2007-01-01</td><td>09:42</td><td>09:15</td><td>12:29</td><td>11:56</td><td>AS</td><td>663</td><td>N649AS</td><td>167</td><td>161</td><td>146</td><td>33</td><td>27</td><td>LAS</td><td>SEA</td><td>866</td><td>3</td><td>18</td><td>0</td><td>null</td><td>0</td><td>27</td><td>0</td><td>6</td><td>0</td><td>0</td><td>33</td></tr><tr><td>2007-01-01T09: ...

# %%
# TEST - Run this cell to test your solution.
count = 0
for s in spark.streams.active:
  if (s.name == myStreamName):
    count = count + 1

dbTest("SS-02-runningCount", 1, count)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# When you are done, stop the stream:

# %%
stopAllStreams()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Stopping the stream delays_python.
# The stream delays_python was stopped.
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png">Write Stream</h2>
#
# Write the stream to an in-memory table
# 1. Use appropriate `format`
# 2. For this exercise, we want to append new records to the results table
# 3. We have configured a 15 second trigger
# 4. Name the query "delays_python"
# 5. Start the query
# 6. Assign the query to `delayQuery`

# %%
# TODO
delayQuery = (delaysDF.writeStream              # From the DataFrame get the DataStreamWriter
             .format("memory")             # Specify the sink format as "memory"
             .outputMode("append")               # Configure the output mode as "append"
             .queryName(myStreamName) # Name the query with myStreamName
             .trigger(processingTime = "15 seconds")               # Use a 15 second trigger
             .start()               # Start the query
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-02-isActive", True, delayQuery.isActive)
dbTest("SS-02-name", myStreamName, delayQuery.name)
# The query's trigger is not available via the Python API

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# Wait until stream is done initializing...

# %%
myStreamName = "delays_python"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3357031427824868&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> myStreamName <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;delays_python&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>untilStreamIsReady<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;delays_python&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-3357031427825063&gt;</span> in <span class="ansi-cyan-fg">untilStreamIsReady</span><span class="ansi-blue-fg">(name, progressions)</span>
# <span class="ansi-green-intense-fg ansi-bold">     99</span> <span class="ansi-green-fg">def</span> untilStreamIsReady<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">,</span> progressions<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    100</span>   <span class="ansi-green-fg">import</span> time
# <span class="ansi-green-fg">--&gt; 101</span><span class="ansi-red-fg">   </span>queries <span class="ansi-blue-fg">=</span> list<span class="ansi-blue-fg">(</span>filter<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> query<span class="ansi-blue-fg">:</span> query<span class="ansi-blue-fg">.</span>name <span class="ansi-blue-fg">==</span> name<span class="ansi-blue-fg">,</span> getActiveStreams<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    102</span>
# <span class="ansi-green-intense-fg ansi-bold">    103</span>   <span class="ansi-green-fg">while</span> <span class="ansi-blue-fg">(</span>len<span class="ansi-blue-fg">(</span>queries<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">==</span> <span class="ansi-cyan-fg">0</span> <span class="ansi-green-fg">or</span> len<span class="ansi-blue-fg">(</span>queries<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>recentProgress<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">&lt;</span> progressions<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">filter</span><span class="ansi-blue-fg">(col, f)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4367</span>     <span class="ansi-blue-fg">+</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">-</span><span class="ansi-blue-fg">+</span>
# <span class="ansi-green-intense-fg ansi-bold">   4368</span>     &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 4369</span><span class="ansi-red-fg">     </span><span class="ansi-green-fg">return</span> _invoke_higher_order_function<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ArrayFilter&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span>col<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span>f<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4370</span>
# <span class="ansi-green-intense-fg ansi-bold">   4371</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">_invoke_higher_order_function</span><span class="ansi-blue-fg">(name, cols, funs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4197</span>     expr <span class="ansi-blue-fg">=</span> getattr<span class="ansi-blue-fg">(</span>expressions<span class="ansi-blue-fg">,</span> name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4198</span>
# <span class="ansi-green-fg">-&gt; 4199</span><span class="ansi-red-fg">     </span>jcols <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>_to_java_column<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>expr<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> cols<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   4200</span>     jfuns <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>_create_lambda<span class="ansi-blue-fg">(</span>f<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> f <span class="ansi-green-fg">in</span> funs<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   4201</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">&lt;listcomp&gt;</span><span class="ansi-blue-fg">(.0)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4197</span>     expr <span class="ansi-blue-fg">=</span> getattr<span class="ansi-blue-fg">(</span>expressions<span class="ansi-blue-fg">,</span> name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4198</span>
# <span class="ansi-green-fg">-&gt; 4199</span><span class="ansi-red-fg">     </span>jcols <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>_to_java_column<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>expr<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> cols<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   4200</span>     jfuns <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>_create_lambda<span class="ansi-blue-fg">(</span>f<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> f <span class="ansi-green-fg">in</span> funs<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   4201</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/column.py</span> in <span class="ansi-cyan-fg">_to_java_column</span><span class="ansi-blue-fg">(col)</span>
# <span class="ansi-green-intense-fg ansi-bold">     44</span>         jcol <span class="ansi-blue-fg">=</span> _create_column_from_name<span class="ans

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.
#
# *   List item
# *   List item
#
# png"> Exercise 5: Stop streaming jobs</h2>
#
# Before we can conclude, we need to shut down all active streams.

# %%
# TODO
for streams in spark.streams.active:# Iterate over all active streams
  try:
    print("stopping " + streams.name)  # A little console output
    streams.stop()     # Stop the stream
    
  except Exception as e:
    print("some error occured")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">stopping delays_python
# </div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-02-numActiveStreams", 0, len(spark.streams.active))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Cleanup<br>
#
# Run the **`Classroom-Cleanup`** cell below to remove any artifacts created by this lesson.

# %%
# %run "../Includes/Classroom-Cleanup"

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Next Steps</h2>
#
# Start the next part, [Time Windows]($../SS 03 - Time Windows).
